# %% [markdown]
# <a href="https://colab.research.google.com/github/TeemoGyllenhaal/Python-g-n-c-b-n/blob/For/VonglapFor.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Bài 1:
# ![12.png](data:image/png;base64,...)

# %%
for dk in range (1000):
  n = int(input("Nhập n: "))
  if n <= 0:
    print ("Số dương nha, nhập lại:")
  else:
    break
n = int(input("Nhập n: "))
Tong = 0
for step in range (1,n+1,1):
    Tong = Tong + step
    step = step + 1
print("Giá trị tổng là: ",Tong)
# Out:
# Nhập n: 5
# Giá trị tổng là:  15

# %% [markdown]
# 1.2:
# ![Biểu đồ không có tiêu đề.drawio (2).png](data:image/png;base64,...)

# %%
for dk in range (1000):
  n = int(input("Nhập n: "))
  if n <= 0:
    print ("Số dương nha, nhập lại:")
  else:
    if n % 2 == 0:
      print ("Số lẻ nha, nhập lại:")
    else:
      break
print ("Đúng rồi !!!")
tong = 0
for step in range(1,n+1,1):
  if step % 2 != 0:
    tong = tong + step
    step = step + 1
  else:
    step = step + 1
print ("Tổng : ",tong)
# Out:
# Nhập n: 2
# Số lẻ nha, nhập lại:
# Nhập n: 4
# Số lẻ nha, nhập lại:
# Nhập n: -4
# Số dương nha, nhập lại:
# Nhập n: 0
# Số dương nha, nhập lại:
# Nhập n: 3
# Đúng rồi !!!
# Tổng :  4

# %% [markdown]
# 1.3:![Biểu đồ không có tiêu đề.drawio (4).png](data:image/png;base64,...)

# %%
for dk in range (1000):
  n = int(input("Nhập n: "))
  if n <= 0:
    print ("Số dương nha, nhập lại:")
  else:
    if n % 2 != 0:
      print ("Số chẵn nha, nhập lại:")
    else:
      break
print ("Đúng rồi !!!")
tong = 0
for step in range(1,n+1,1):
  if step % 2 ==0:
    tong += step
    step +=1 
  else:
    step +=1
print ("Tổng : ",tong)
# Out:
# Nhập n: -5
# Số dương nha, nhập lại:
# Nhập n: -8
# Số dương nha, nhập lại:
# Nhập n: 3
# Số chẵn nha, nhập lại:
# Nhập n: -4
# Số dương nha, nhập lại:
# Nhập n: 0
# Số dương nha, nhập lại:
# Nhập n: 2
# Đúng rồi !!!
# Tổng :  2

# %% [markdown]
# 1.4:![Biểu đồ không có tiêu đề.drawio (12).png](data:image/png;base64,...)

# %%
from math import log, exp
for dk in range (1000):
  n = int(input("Nhập n: "))
  if n <= 0:
    print ("Số dương nha, nhập lại:")
  else:
    break
Tong = 0
for i in range (1,n+1,1):
  Tong += log(i)
  i += 1
print ("Tổng :",Tong)
# Out:
# Nhập n: 3
# Tổng : 1.791759469228055

# %% [markdown]
# 1.5:![Biểu đồ không có tiêu đề.drawio (11).png](data:image/png;base64,...)

# %%
for dk in range (1000):
  n = int(input("Nhập n: "))
  if n <= 0:
    print ("Số dương nha, nhập lại:")
  else:
    break
Tong = 0
for i in range (1,n+1,1):
  Tong += 1/i
  i += 1
print ("Tổng :",Tong)
# Out:
# Nhập n: 4
# Tổng : 2.083333333333333

# %% [markdown]
# Bài 2:![Biểu đồ không có tiêu đề.drawio (10).png](data:image/png;base64,...)

# %%
for dk in range (1000):
  n = int(input("Nhập n: "))
  if n <= 0:
    print ("Số dương nha, nhập lại:")
  else:
    break
P = 1
for i in range (1,n+1,1):
  P*=i
print("Giá trị của P là:", P)
# Out:
# Nhập n: 4
# Giá trị của P là: 24

# %% [markdown]
# 2.2:![Biểu đồ không có tiêu đề.drawio (9).png](data:image/png;base64,...)

# %%
for dk in range (1000):
  n = int(input("Nhập n: "))
  if n <= 0:
    print ("Số dương nha, nhập lại:")
  else:
    break
P = 1
for i in range (1,n+1,1):
  P*= (1/i)
print ("Giá trị của P là: ",P)
# Out:
# Nhập n: 4
# Giá trị của P là:  0.041666666666666664

# %% [markdown]
# 2.3![Biểu đồ không có tiêu đề.drawio (13).png](data:image/png;base64,...)

# %%
for dk in range (1000):
  n = int(input("Nhập n: "))
  if n <= 0:
    print ("Số dương nha, nhập lại:")
  else:
    if n % 2 == 0:
      print ("Số lẻ nha, nhập lại:")
    else:
      break
P = 1
for i in range (1,n+1,2):
  P*=i
print ("Giá trị của P là: ",P)
# Out:
# Nhập n: 9
# Giá trị của P là:  945

# %% [markdown]
# 2.4: ![Biểu đồ không có tiêu đề.drawio (14).png](data:image/png;base64,...)

# %%
for dk in range (1000):
  n = int(input("Nhập n: "))
  if n <= 0:
    print ("Số dương nha, nhập lại:")
  else:
    if n % 2 != 0:
      print ("Số chẵn nha, nhập lại:")
    else:
      break
P = 1
for i in range (2,n+1,2):
  P*=i
print ("Giá trị của P là: ",P)
# Out:
# Nhập n: 5
# Số chẵn nha, nhập lại:
# Nhập n: 6
# Giá trị của P là:  48
